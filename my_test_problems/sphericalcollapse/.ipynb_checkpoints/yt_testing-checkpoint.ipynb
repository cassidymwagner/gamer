# %%
import argparse
import sys
import yt
import numpy as np

# %%
idx_start = 0
idx_end = 0
didx = 1

colormap = 'viridis_r'
field = 'density'
center_mode = 'c'
dpi = 1000

code_units = { "length_unit":(1.0,"kpc"),
               "time_unit"  :(3.08567758096e+13,"s"),
               "mass_unit"  :(1.4690033e+36,"g") }

# %%
ts = yt.load(['Data_%06d'%idx for idx in range(idx_start,idx_end+1,didx)],
            units_override=code_units)

# %%
ds = yt.load("Data_000000", units_override=code_units)
# Out:
# yt : [WARNING  ] 2018-06-26 17:33:04,862 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2018-06-26 17:33:04,863 Overriding length_unit: 1 kpc.
# yt : [INFO     ] 2018-06-26 17:33:04,864 Overriding time_unit: 3.08568e+13 s.
# yt : [INFO     ] 2018-06-26 17:33:04,865 Overriding mass_unit: 1.469e+36 g.
# yt : [INFO     ] 2018-06-26 17:33:04,873 Parameters: current_time              = 1e-05
# yt : [INFO     ] 2018-06-26 17:33:04,874 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-06-26 17:33:04,875 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-06-26 17:33:04,875 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-06-26 17:33:04,876 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2018-06-26 17:33:04,877 Parameters: current_redshift          = 99998.99999999999
# yt : [INFO     ] 2018-06-26 17:33:04,877 Parameters: omega_lambda              = 0.0
# yt : [INFO     ] 2018-06-26 17:33:04,878 Parameters: omega_matter              = 1.0
# yt : [INFO     ] 2018-06-26 17:33:04,878 Parameters: hubble_constant           = 0.7

# %%
reg = ds.unit_registry

for un in reg.keys():
    if un.startswith('code_'):
        fmt_tup = (un, reg.lut[un][0], str(reg.lut[un][1]))
        print ("Unit name:      {:<15}\nCGS conversion: {:<15}\nDimensions:     {:<15}\n".format(*fmt_tup))
# Out:
# Unit name:      code_length
# CGS conversion: 3.0856775809623245e+21
# Dimensions:     (length)
#
# Unit name:      code_mass
# CGS conversion: 1.4690033e+36
# Dimensions:     (mass)
#
# Unit name:      code_density
# CGS conversion: 5.000013028280416e-29
# Dimensions:     (mass)/(length)**3
#
# Unit name:      code_specific_energy
# CGS conversion: 1.000000000001507e+16
# Dimensions:     (length)**2/(time)**2
#
# Unit name:      code_time
# CGS conversion: 30856775809600.0
# Dimensions:     (time)
#
# Unit name:      code_magnetic
# CGS conversion: 1.0
# Dimensions:     sqrt((mass))/(sqrt((length))*(time))
#
# Unit name:      code_temperature
# CGS conversion: 1.0
# Dimensions:     (temperature)
#
# Unit name:      code_pressure
# CGS conversion: 5.00001302828795e-13
# Dimensions:     (mass)/((length)*(time)**2)
#
# Unit name:      code_velocity
# CGS conversion: 100000000.00007534
# Dimensions:     (length)/(time)
#
# Unit name:      code_metallicity
# CGS conversion: 1.0
# Dimensions:     1

# %%
p = yt.ProjectionPlot(ds, 'y', 'density')
p.show()
# Out:
# yt : [INFO     ] 2018-06-26 17:33:16,954 Projection completed
# yt : [INFO     ] 2018-06-26 17:33:16,955 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:16,956 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:16,957 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:16,957 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:16,959 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2018-06-26 17:33:16,978 Plot image for field ('gas', 'density') has both positive and negative values. Min = -0.000000, Max = 0.000001.
# yt : [WARNING  ] 2018-06-26 17:33:16,979 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds, 'y', 'density')
slc.show()
# Out:
# yt : [INFO     ] 2018-06-26 17:33:17,558 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:17,559 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:17,560 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:17,560 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:17,561 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2018-06-26 17:33:17,767 Plot image for field ('gas', 'density') has both positive and negative values. Min = -0.000000, Max = 0.000000.
# yt : [WARNING  ] 2018-06-26 17:33:17,768 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for ds in ts.piter():
    
    sz = yt.SlicePlot(ds,'z',field,center=center_mode)
#     sz.set_zlim(field,0.0,3)
    sz.set_log(field,False)
    sz.set_cmap(field,colormap)
    sz.set_unit(field,'g/cm**3')
    sz.set_axes_unit('kpc')
#     sz.annotate_timestamp(time_unit='code_time',corner='upper_right',
#                          time_format='t = {time:.4f} {units}')
    sz.annotate_grids(periodic=False)
    sz.zoom(5)
    sz.show()
# Out:
# yt : [WARNING  ] 2018-06-26 17:33:25,950 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2018-06-26 17:33:25,950 Overriding length_unit: 1 kpc.
# yt : [INFO     ] 2018-06-26 17:33:25,951 Overriding time_unit: 3.08568e+13 s.
# yt : [INFO     ] 2018-06-26 17:33:25,952 Overriding mass_unit: 1.469e+36 g.
# yt : [INFO     ] 2018-06-26 17:33:25,960 Parameters: current_time              = 1e-05
# yt : [INFO     ] 2018-06-26 17:33:25,961 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-06-26 17:33:25,961 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-06-26 17:33:25,962 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-06-26 17:33:25,963 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2018-06-26 17:33:25,963 Parameters: current_redshift          = 99998.99999999999
# yt : [INFO     ] 2018-06-26 17:33:25,964 Parameters: omega_lambda              = 0.0
# yt : [INFO     ] 2018-06-26 17:33:25,964 Parameters: omega_matter              = 1.0
# yt : [INFO     ] 2018-06-26 17:33:25,965 Parameters: hubble_constant           = 0.7
# yt : [INFO     ] 2018-06-26 17:33:29,299 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:29,300 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:29,301 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:29,301 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:29,303 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2018-06-26 17:33:29,515 Plot image for field ('gas', 'density') has both positive and negative values. Min = -0.000000, Max = 0.000000.
# yt : [WARNING  ] 2018-06-26 17:33:29,515 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2018-06-26 17:33:29,604 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# /usr/lib/python3.6/site-packages/yt-3.5.dev0-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1372: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# yt : [WARNING  ] 2018-06-26 17:33:29,741 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p = yt.ProjectionPlot(ds, "y", "density", weight_field="temperature")
# p.zoom(2.5)
p.show()
# p.save(name='sphericalcollapse_temp_weirdbox.png',mpl_kwargs={"dpi":dpi})
# Out:
# yt : [INFO     ] 2018-06-26 17:33:40,344 Projection completed
# yt : [INFO     ] 2018-06-26 17:33:40,345 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:40,346 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:40,347 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:40,348 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-06-26 17:33:40,349 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2018-06-26 17:33:40,368 Plot image for field ('gas', 'density') has both positive and negative values. Min = -0.000000, Max = 0.000000.
# yt : [WARNING  ] 2018-06-26 17:33:40,369 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.periodicity = (True,True,True)

sc = yt.create_scene(ds, lens_type='perspective')

sc.camera.set_width(ds.quan(100,'kpc'))
source = sc[0]

# source.tfh.set_bounds((1e-31, 5e-26))
# source.tfh.set_log(True)
# source.tfh.grey_opacity = False

source.set_field('density')
source.set_log(True)
# source.set_use_ghost_zones(True)

bounds = (3.5e-30, 10e-28)

# Since this rendering is done in log space, the transfer function needs
# to be specified in log space.
tf = yt.ColorTransferFunction(np.log10(bounds))

tf.add_layers(7, colormap='viridis_r')

source.tfh.tf = tf
source.tfh.bounds = bounds

sc.camera.zoom(5)
sc.show(sigma_clip=6.0)
# sc.save(fname='sphericalcollapse_temp_symmgeom.png',sigma_clip=6.0)

source.tfh.plot(profile_field='density')
# Out:
# yt : [INFO     ] 2018-06-26 17:33:47,621 Setting default field to ('gas', 'density')
# yt : [INFO     ] 2018-06-26 17:33:47,671 Rendering scene (Can take a while).
# yt : [INFO     ] 2018-06-26 17:33:47,672 Creating volume
# /usr/lib/python3.6/site-packages/yt-3.5.dev0-py3.6-linux-x86_64.egg/yt/units/yt_array.py:1351: RuntimeWarning: invalid value encountered in log10
#   out_arr = func(np.asarray(inp), out=out, **kwargs)
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (Data_000000): , center=[1.54283879e+21 1.54283879e+21 1.54283879e+21] cm, left_edge=[0. 0. 0.] cm, right_edge=[3.08567758e+21 3.08567758e+21 3.08567758e+21] cm transfer_function:None
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829] dimensionless
# 	width:[ 20.  20. 100.] unitary
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:perspective
# 	viewpoint:[-28.36751346 -28.36751346 -28.36751346] code_length

# %%
# sc = yt.create_scene(ds, lens_type='perspective')

# sc.camera.set_width(ds.quan(100,'kpc'))
# source = sc[0]

# # source.tfh.set_bounds((1e-31, 5e-26))
# # source.tfh.set_log(True)
# # source.tfh.grey_opacity = False

# source.set_field('temperature')
# source.set_log(True)
# source.set_use_ghost_zones(True)

# bounds = (2e1,6e2)

# # Since this rendering is done in log space, the transfer function needs
# # to be specified in log space.
# tf = yt.ColorTransferFunction(np.log10(bounds))

# tf.add_layers(7, colormap='viridis_r')

# source.tfh.tf = tf
# source.tfh.bounds = bounds

# sc.camera.zoom(7)
# sc.show(sigma_clip=6.0)
# # sc.save(fname='sphericalcollapse_temp_symmgeom.png',sigma_clip=6.0)

# source.tfh.plot(profile_field='temperature')

# %%
# ts = yt.load(['../blastwave/Data_%06d'%idx for idx in range(9,9+1,didx)])

# %%
# for ds in ts.piter():
    
#     sz = yt.SlicePlot(ds,'z',field,center=center_mode)
#     sz.set_zlim(field,0.0,3)
#     sz.set_log(field,False)
#     sz.set_cmap(field,colormap)
#     sz.set_unit(field,'code_mass/code_length**3')
#     sz.set_axes_unit('code_length')
#     sz.annotate_timestamp(time_unit='code_time',corner='upper_right',
#                          time_format='t = {time:.4f} {units}')
#     sz.annotate_grids(periodic=False)
#     sz.show()

# %%
# ds.periodicity = (True,True,True)

# sc = yt.create_scene(ds, lens_type='perspective')

# sc.camera.set_width(ds.quan(100,'kpc'))
# source = sc[0]

# # source.tfh.set_bounds((1e-3, 4))
# # source.tfh.set_log(True)
# # source.tfh.grey_opacity = False

# source.set_field('density')
# source.set_log(True)
# source.set_use_ghost_zones(True)

# bounds = (0.6, 4.5)

# tf = yt.ColorTransferFunction(np.log10(bounds))

# tf.add_layers(7, colormap='viridis_r')

# source.tfh.tf = tf
# source.tfh.bounds = bounds

# sc.camera.zoom(1)
# sc.show(sigma_clip=6.0)
# # sc.save(fname='sphericalcollapse_temp_symmgeom.png',sigma_clip=6.0)

# source.tfh.plot(profile_field='density')

# %%
# sc = yt.create_scene(ds, lens_type='perspective')

# sc.camera.set_width(ds.quan(100,'kpc'))
# source = sc[0]

# # source.tfh.set_bounds((1e-3, 4))
# # source.tfh.set_log(True)
# # source.tfh.grey_opacity = False

# source.set_field('temperature')
# source.set_log(True)
# source.set_use_ghost_zones(True)

# bounds = (10e-8, 5e-5)

# # Since this rendering is done in log space, the transfer function needs
# # to be specified in log space.
# tf = yt.ColorTransferFunction(np.log10(bounds))

# tf.add_layers(7, colormap='viridis_r')

# source.tfh.tf = tf
# source.tfh.bounds = bounds

# sc.camera.zoom(3)
# sc.show(sigma_clip=6.0)
# # sc.save(fname='sphericalcollapse_temp_symmgeom.png',sigma_clip=6.0)

# source.tfh.plot(profile_field='temperature')
