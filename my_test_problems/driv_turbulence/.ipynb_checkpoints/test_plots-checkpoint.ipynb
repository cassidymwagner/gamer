# %%
import argparse
import sys
import yt
import numpy as np
import pylab
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams['figure.figsize'] = (12,9)
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
idx_start = 0
idx_end = 312
didx = 15

colormap = 'arbre'
field = 'density'
center_mode = 'c'
dpi = 1000

code_units = { "length_unit":(1.0,"kpc"),
               "time_unit"  :(3.08567758096e+13,"s"),
               "mass_unit"  :(1.4690033e+36,"g") }

# %%
pwd
# Out:
# '/home/cass/applications/gamer/bin/blastwave'

# %%
ts = yt.load(['Data_%06d'%idx for idx in range(idx_start,idx_end+1,didx)])

# %%
ds = yt.load("Data_000000")
# Out:
# yt : [WARNING  ] 2018-08-13 12:20:20,743 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-08-13 12:20:20,744 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-08-13 12:20:20,745 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-08-13 12:20:20,746 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-08-13 12:20:20,761 Parameters: current_time              = 0.0
# yt : [INFO     ] 2018-08-13 12:20:20,763 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-08-13 12:20:20,764 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-08-13 12:20:20,765 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-08-13 12:20:20,766 Parameters: cosmological_simulation   = 0

# %%
ds.index.grids[0]["pressure"].ravel(order='F').mean()
# Out:
# 1.0000000007141345 dyne/cm**2

# %%
pressure = ds.index.grids[0]["pressure"].ravel(order='F')
M_s = ds.index.grids[0]["mach_number"].ravel(order='F')
c_s = ds.index.grids[0]["sound_speed"].ravel(order='F')
v_mag = ds.index.grids[0]["velocity_magnitude"].ravel(order='F')
density = ds.index.grids[0]["density"].ravel(order='F')

# %%
print('Mean pressure:',pressure.mean())
print('Mean mach number:',M_s.min(),M_s.max())
# print('Mean sound speed:',c_s)
# print('Mean velocity magntiude:',v_mag)
# print('Mean density:',density)
# print('Calculated sound speed:',
#       np.sqrt(1.001*pressure/density))
# Out:
# Mean pressure: 1.0000000007141345 dyne/cm**2
# Mean mach number: 4.7102873334935 dimensionless 7.759598442110412 dimensionless

# %%
for ds in ts.piter():
    
    sz = yt.SlicePlot(ds,'y','density')
    sz.set_zlim(field,10e-32,10e-27)
    sz.set_log(field,True)
    sz.set_cmap(field,colormap)
#     sz.set_unit(field,'g/cm**3')
#     sz.set_axes_unit('kpc')
#     sz.annotate_timestamp(time_unit='code_time',corner='upper_right',
#                          time_format='t = {time:.4f} {units}')
#     sz.annotate_grids(periodic=False)
#     sz.show()
#     sz.save(name=str(ds)+'_SlicePlot_Density.png')

# %%
for ds in ts.piter():
    
    sz = ds.r[:].profile("velocity_magnitude", "cell_volume", weight_field=None).plot()
    sz.set_xlim(3e6,8e9)
    sz.set_ylim('cell_volume',10e56,15e63)
#     sz.show()
    sz.save(name=str(ds)+'_PhasePlot.png')

# %%
for ds in ts.piter():
    
    sz = yt.ProjectionPlot(ds,'y','density',weight_field='density')
    sz.set_zlim(field,10e-29,10e-27)
    sz.set_log(field,True)
    sz.set_cmap(field,colormap)
#     sz.set_unit(field,'g/cm**3')
#     sz.set_axes_unit('kpc')
#     sz.annotate_timestamp(time_unit='code_time',corner='upper_right',
#                          time_format='t = {time:.4f} {units}')
#     sz.annotate_grids(periodic=False)
#     sz.show()
#     sz.save(name='ProjectionPlot_Density_' + str(ds) + '.png')

# %% [markdown]
# s = yt.SlicePlot(ds,'y','density')
# s.show()

# %%
s2 = yt.SlicePlot(ds,'y','pressure')
s2.show()
# Out:
# yt : [INFO     ] 2018-08-13 12:20:42,863 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:42,866 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:42,870 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:42,874 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:42,878 Making a fixed resolution buffer of (('gas', 'pressure')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p = yt.ProjectionPlot(ds, 'y', 'density')
p.show()
# Out:
# yt : [INFO     ] 2018-08-13 12:20:51,418 Projection completed
# yt : [INFO     ] 2018-08-13 12:20:51,427 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:51,428 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:51,438 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:51,438 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:20:51,448 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p = yt.ProjectionPlot(ds, 'y', 'temperature')
p.show()
# Out:
# yt : [INFO     ] 2018-08-13 12:21:07,370 Projection completed
# yt : [INFO     ] 2018-08-13 12:21:07,376 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:21:07,377 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:21:07,379 xlim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:21:07,381 ylim = 0.000000 1.000000
# yt : [INFO     ] 2018-08-13 12:21:07,384 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.periodicity = (True,True,True)

sc = yt.create_scene(ds, lens_type='perspective')

sc.camera.set_width(ds.quan(100,'kpc'))
source = sc[0]

# source.tfh.set_bounds((1e-31, 5e-26))
# source.tfh.set_log(True)
# source.tfh.grey_opacity = False

source.set_field('density')
source.set_log(True)
# source.set_use_ghost_zones(True)

bounds = (3.5e-3, 1e2)

# Since this rendering is done in log space, the transfer function needs
# to be specified in log space.
tf = yt.ColorTransferFunction(np.log10(bounds))

tf.add_layers(5, colormap='viridis_r')

source.tfh.tf = tf
source.tfh.bounds = bounds

# sc.camera.zoom(5)
sc.show(sigma_clip=4.0)
# sc.save(fname='sphericalcollapse_temp_symmgeom.png',sigma_clip=6.0)

source.tfh.plot(profile_field='density')

# %%
# ms = sc.get_source()
# ms.cmap = 'viridis_r'

# cam = sc.camera
# cam.focus = ds.arr([0.0, 0.0, 0.0], 'code_length')
# cam_pos = ds.arr([-3.0, -3.0, -3.0], 'code_length')
# north_vector = ds.arr([0.0, -1.0, -1.0], 'dimensionless')
# cam.set_position(cam_pos, north_vector)

# cam.resolution = (800, 800)

# cam.steady_north = True

# num_frames = 20
# for i in range(num_frames):
#     cam.rotate(2.0*np.pi/num_frames)
#     sc.render()
#     sc.save('/home/cass/desktop/turk_research/images/surface_render_%.4d.png' % i)

# %%
fields = ['density','velocity_magnitude','velocity_x','velocity_y',
          'velocity_z']

# %%
for i in fields:
    for j in ['x','y','z']:
        s = yt.SlicePlot(ds,j,i)
        s.show()
#         s.save(name=str(i)+ '_' + str(j) + '_slice.png')

# %%
alld = ds.all_data()

# %%
E_k = []
M_s = []
rho_extr = []
times = []
for ds in ts:
    dd = ds.all_data()
    rho_extr.append(dd.quantities.extrema("density"))
    E_k.append(dd.mean("kinetic_energy"))
    M_s.append(dd.mean("mach_number"))
    times.append(ds.current_time)
rho_extr = np.array(rho_extr)
E_k = np.array(E_k)
M_s = np.array(M_s)
# Out:
# yt : [WARNING  ] 2018-07-02 14:24:42,088 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:24:42,089 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:24:42,090 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:24:42,091 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:24:42,099 Parameters: current_time              = 0.0
# yt : [INFO     ] 2018-07-02 14:24:42,100 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:24:42,101 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:24:42,102 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:24:42,103 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:24:55,091 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:24:55,093 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:24:55,094 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:24:55,095 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:24:55,105 Parameters: current_time              = 0.007500000000000003
# yt : [INFO     ] 2018-07-02 14:24:55,106 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:24:55,107 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:24:55,108 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:24:55,109 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:25:08,974 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:25:08,976 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:25:08,977 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:25:08,978 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:25:08,987 Parameters: current_time              = 0.01500000000000001
# yt : [INFO     ] 2018-07-02 14:25:08,988 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:25:08,989 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:25:08,990 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:25:08,991 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:25:23,073 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:25:23,075 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:25:23,077 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:25:23,078 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:25:23,087 Parameters: current_time              = 0.022500000000000017
# yt : [INFO     ] 2018-07-02 14:25:23,088 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:25:23,089 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:25:23,090 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:25:23,091 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:25:37,607 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:25:37,610 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:25:37,611 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:25:37,612 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:25:37,621 Parameters: current_time              = 0.030000000000000023
# yt : [INFO     ] 2018-07-02 14:25:37,622 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:25:37,622 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:25:37,623 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:25:37,624 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:25:51,672 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:25:51,674 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:25:51,675 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:25:51,677 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:25:51,685 Parameters: current_time              = 0.037500000000000026
# yt : [INFO     ] 2018-07-02 14:25:51,686 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:25:51,687 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:25:51,688 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:25:51,689 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:26:05,717 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:26:05,719 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:26:05,720 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:26:05,721 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:26:05,730 Parameters: current_time              = 0.04500000000000003
# yt : [INFO     ] 2018-07-02 14:26:05,731 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:26:05,732 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:26:05,733 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:26:05,734 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:26:20,247 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:26:20,249 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:26:20,250 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:26:20,251 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:26:20,261 Parameters: current_time              = 0.05250000000000004
# yt : [INFO     ] 2018-07-02 14:26:20,261 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:26:20,262 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:26:20,263 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:26:20,264 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:26:34,433 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:26:34,435 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:26:34,437 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:26:34,438 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:26:34,448 Parameters: current_time              = 0.060000000000000046
# yt : [INFO     ] 2018-07-02 14:26:34,448 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:26:34,449 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:26:34,450 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:26:34,451 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:26:48,531 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:26:48,533 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:26:48,534 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:26:48,535 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:26:48,544 Parameters: current_time              = 0.06750000000000005
# yt : [INFO     ] 2018-07-02 14:26:48,545 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:26:48,546 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:26:48,547 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:26:48,548 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:27:02,448 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:27:02,451 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:27:02,452 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:27:02,452 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:27:02,462 Parameters: current_time              = 0.07500000000000005
# yt : [INFO     ] 2018-07-02 14:27:02,463 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:27:02,464 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:27:02,465 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:27:02,465 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:27:16,296 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:27:16,298 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:27:16,300 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:27:16,301 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:27:16,311 Parameters: current_time              = 0.08250000000000006
# yt : [INFO     ] 2018-07-02 14:27:16,312 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:27:16,313 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:27:16,314 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:27:16,315 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:27:30,434 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:27:30,436 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:27:30,437 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:27:30,438 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:27:30,447 Parameters: current_time              = 0.09000000000000007
# yt : [INFO     ] 2018-07-02 14:27:30,447 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:27:30,448 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:27:30,449 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:27:30,450 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:27:44,147 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:27:44,149 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:27:44,150 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:27:44,151 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:27:44,160 Parameters: current_time              = 0.09750000000000007
# yt : [INFO     ] 2018-07-02 14:27:44,161 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:27:44,162 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:27:44,163 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:27:44,164 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:27:57,936 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:27:57,938 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:27:57,938 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:27:57,939 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:27:57,947 Parameters: current_time              = 0.10500000000000008
# yt : [INFO     ] 2018-07-02 14:27:57,948 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:27:57,949 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:27:57,949 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:27:57,950 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:28:11,683 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:28:11,685 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:28:11,686 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:28:11,687 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:28:11,696 Parameters: current_time              = 0.11250000000000009
# yt : [INFO     ] 2018-07-02 14:28:11,696 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:28:11,697 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:28:11,698 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:28:11,699 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:28:25,057 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:28:25,058 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:28:25,060 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:28:25,061 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:28:25,069 Parameters: current_time              = 0.12000000000000009
# yt : [INFO     ] 2018-07-02 14:28:25,070 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:28:25,071 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:28:25,072 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:28:25,073 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:28:38,434 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:28:38,436 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:28:38,437 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:28:38,438 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:28:38,447 Parameters: current_time              = 0.12750000000000009
# yt : [INFO     ] 2018-07-02 14:28:38,448 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:28:38,449 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:28:38,450 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:28:38,451 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:28:51,954 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:28:51,955 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:28:51,956 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:28:51,957 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:28:51,965 Parameters: current_time              = 0.1350000000000001
# yt : [INFO     ] 2018-07-02 14:28:51,966 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:28:51,967 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:28:51,968 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:28:51,969 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:29:05,306 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:29:05,308 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:29:05,309 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:29:05,310 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:29:05,319 Parameters: current_time              = 0.1425000000000001
# yt : [INFO     ] 2018-07-02 14:29:05,319 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:29:05,320 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:29:05,321 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:29:05,322 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2018-07-02 14:29:18,745 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2018-07-02 14:29:18,747 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2018-07-02 14:29:18,748 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2018-07-02 14:29:18,749 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2018-07-02 14:29:18,757 Parameters: current_time              = 0.1500000000000001
# yt : [INFO     ] 2018-07-02 14:29:18,758 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-07-02 14:29:18,759 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-02 14:29:18,760 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-07-02 14:29:18,761 Parameters: cosmological_simulation   = 0

# %%
pylab.semilogx(times, np.log10((E_k)/alld.mean('kinetic_energy')),lw=4) 
pylab.ylabel(r"$\log_{10} \mathrm{E/E_{0}}$",fontsize=30)
pylab.xlabel(r"$\log_{10} \mathrm{t}$",fontsize=30)                        # need t_s, not sure what that is
pylab.xlim(0, 0.2)
pylab.xticks(fontsize=20)
pylab.yticks(fontsize=20)
pylab.show()
# Out:
# /home/cwagner4/applications/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3129: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '

# %%
pylab.plot(times, M_s,lw=4)
pylab.ylabel("Mach number",fontsize=30)
pylab.xlabel("Time",fontsize=30)
pylab.xlim(0, 0.2)
pylab.xticks(fontsize=20)
pylab.yticks(fontsize=20)
pylab.show()

# %%
pylab.plot(times, rho_extr[:,1],lw=4)
pylab.ylabel("Maximum Density",fontsize=30)
pylab.xlabel("Time",fontsize=30)
pylab.xlim(0, 0.2)
pylab.xticks(fontsize=20)
pylab.yticks(fontsize=20)
pylab.show()

# %%
pylab.plot(times, rho_extr[:,0],lw=4)
pylab.ylabel("Minimum Density",fontsize=30)
pylab.xlabel("Time",fontsize=30)
pylab.xlim(0, 0.2)
pylab.xticks(fontsize=20)
pylab.yticks(fontsize=20)
pylab.show()

# %%
pylab.plot(times, M_a,lw=4)
pylab.ylabel("Alfven number",fontsize=30)
pylab.xlabel("Time",fontsize=30)
pylab.xlim(0, 0.2)
pylab.xticks(fontsize=20)
pylab.yticks(fontsize=20)
pylab.show()
